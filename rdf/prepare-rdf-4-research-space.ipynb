# %% [markdown]
# # Prepare DraCor-RDF data for Research Space
#
# Notebook to get RDF data from a local DraCor instance (using docker); data is parsed, validated and stored locally to be then ingested into a Research Space instance.

# %%
import requests
import json

# %%
#Generic function to handle DraCor-API requests (see intro-notebook)
#corpusname:str -> []
def get(**kwargs):
    #corpusname=corpusname
    #playname=playname
    #apibase="https://dracor.org/api/"
    #method=method
    #parse_json: True
    
    #could set different apibase, e.g. https://staging.dracor.org/api/ [not recommended, pls use the production server]
    if "apibase" in kwargs:
        if kwargs["apibase"].endswith("/"):
            apibase = kwargs["apibase"]
        else:
            apibase = kwargs["apibase"] + "/"
    else:
        #use default
        apibase = "https://dracor.org/api/"
    if "corpusname" in kwargs and "playname" in kwargs:
        # used for /api/corpora/{corpusname}/play/{playname}/
        if "method" in kwargs:
            request_url = apibase + "corpora/" + kwargs["corpusname"] + "/play/" + kwargs["playname"] + "/" + kwargs["method"]
        else:
            request_url = apibase + "corpora/" + kwargs["corpusname"] + "/play/" + kwargs["playname"]
    elif "corpusname" in kwargs and not "playname" in kwargs:
        if "method" in kwargs:
            request_url = apibase + "corpora/" + kwargs["corpusname"] + "/" + kwargs["method"]
        else:
            request_url = apibase + "corpora/" + kwargs["corpusname"] 
    elif "method" in kwargs and not "corpusname" in kwargs and not "playname" in kwargs:
            request_url = apibase + kwargs["method"]
    else: 
        #nothing set
        request = request_url = apibase + "info"
    
    #debug
    #print(request_url)
    
    #send the response
    r = requests.get(request_url)
    if r.status_code == 200:
        #success!
        if "parse_json" in kwargs:
            if kwargs["parse_json"] == True:
                json_data = json.loads(r.text)
                return json_data
            else:
                return r.text
        else:
            return r.text
    else:
        raise Exception("Request was not successful. Server returned status code: "  + str(r.status_code))

# %%
#test with local running DraCor instance
get(method="info", parse_json=True, apibase="http://localhost:8080/exist/restxq/")
# Out:
# {'existdb': '5.3.0',
#  'name': 'DraCor API',
#  'status': 'beta',
#  'version': '0.82.1-30-g63f3625'}

# %% [markdown]
# Normally, RDf data is generated upon ingest and when calling the designated download endpoint, the pre-generated RDF is returned. I Implemented a new experimental local endpoint to the instance used for this notebook, that will generate the rdf-data on the fly when called.
#
# xQuery-Code of the function, that has been added to the `api.xqm` module:
#
# ```
# (:~
#  : Get rdf of a play generated on the fly
#  :
#  : @param $corpusname Corpus name
#  : @param $playname Play name
#  : @result rdf representation of a play
#  :)
# declare
#   %rest:GET
#   %rest:path("/corpora/{$corpusname}/play/{$playname}/generate-rdf")
#   %rest:produces("application/rdf+xml")
#   %output:media-type("application/rdf+xml")
# function api:generate-rdf-on-the-fly($corpusname, $playname) {
#   let $doc := dutil:get-doc($corpusname, $playname)/tei:TEI
#   return
#     if (not($doc)) then
#       <rest:response>
#         <http:response status="404"/>
#       </rest:response>
#     else
#         try {
#             let $rdf-transformed := drdf:play-to-rdf($doc)
#             return
#                 (
#                 <rest:response>
#                     <http:response status="200"/>
#                 </rest:response>,
#                 $rdf-transformed
#                 )
#         }
#         catch * {
#             <rest:response>
#                 <http:response status="500"/>
#             </rest:response>
#         }
#
# };
# ```

# %%
# http://localhost:8080/exist/restxq/corpora/ger/play/gutzkow-richard-savage/generate-rdf
corpusname = "ger"
playname = "gutzkow-richard-savage"
method = "generate-rdf"


test_rdf = get(method=method, playname=playname, corpusname=corpusname, parse_json=False, apibase="http://localhost:8080/exist/restxq/")
print(test_rdf)
# Out:
# <rdf:RDF xmlns:schema="http://schema.org/" xmlns:owl="http://www.w3.org/2002/07/owl#" xmlns:crmcls="https://clsinfra.io/ontologies/CRMcls/" xmlns:dracon="http://dracor.org/ontology#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:crm="http://www.cidoc-crm.org/cidoc-crm/" xmlns:frbroo="http://iflastandards.info/ns/fr/frbr/frbroo/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <rdf:type rdf:resource="http://dracor.org/ontology#play"/>
#         <rdf:type rdf:resource="https://clsinfra.io/ontologies/CRMcls/X2_Corpus_Document"/>
#         <rdfs:label xml:lang="ger">Gutzkow, Karl: Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen</rdfs:label>
#         <dc:title xml:lang="ger">Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen</dc:title>
#         <dc:creator xml:lang="ger">Gutzkow, Karl</dc:creator>
#         <dc:source>Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].</dc:source>
#         <rdfs:seeAlso rdf:resource="https://dracor.org/ger/gutzkow-richard-savage"/>
#         <dracon:in_corpus rdf:resource="https://dracor.org/entity/corpus/ger"/>
#         <crm:P148i_is_component_of rdf:resource="https://dracor.org/entity/corpus/ger"/>
#         <dracon:writtenYear>1839</dracon:writtenYear>
#         <dracon:printYear>1842</dracon:printYear>
#         <dracon:premiereYear>1839</dracon:premiereYear>
#         <dracon:normalisedYear rdf:datatype="http://www.w3.org/2001/XMLSchema#gYear">1839</dracon:normalisedYear>
#         <dracon:numOfSegments rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">30</dracon:numOfSegments>
#         <dracon:numOfActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:numOfActs>
#         <dracon:numOfLines rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">25</dracon:numOfLines>
#         <dracon:numOfParagraphs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">480</dracon:numOfParagraphs>
#         <dracon:numOfSpeakers rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">28</dracon:numOfSpeakers>
#         <dracon:numOfSpeakersMale rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">24</dracon:numOfSpeakersMale>
#         <dracon:numOfSpeakersFemale rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3</dracon:numOfSpeakersFemale>
#         <dracon:numOfSpeakersUnknown rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:numOfSpeakersUnknown>
#         <dracon:numOfSpeakerGroups rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:numOfSpeakerGroups>
#         <dracon:allInIndex rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.9</dracon:allInIndex>
#         <dracon:allInSegment rdf:resource="https://dracor.org/entity/ger000006/segment/27"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/title/main/ger">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E35_Title"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [main title]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/title/main"/>
#         <crm:P102i_is_title_of rdf:resource="https://dracor.org/entity/ger000006"/>
#         <crm:P72_has_language rdf:resource="https://dracor.org/entity/language/ger"/>
#         <rdf:value>Richard Savage oder Der Sohn einer Mutter</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <crm:P102_has_title rdf:resource="https://dracor.org/entity/ger000006/title/main/ger"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/title/sub/ger">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E35_Title"/>
#         <rdfs:label>Trauerspiel in fünf Aufzügen [subtitle]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/title/sub"/>
#         <crm:P102i_is_title_of rdf:resource="https://dracor.org/entity/ger000006"/>
#         <crm:P72_has_language rdf:resource="https://dracor.org/entity/language/ger"/>
#         <rdf:value>Trauerspiel in fünf Aufzügen</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <crm:P102_has_title rdf:resource="https://dracor.org/entity/ger000006/title/sub/ger"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E39_Actor"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#author"/>
#         <rdfs:label xml:lang="ger">Gutzkow, Karl</rdfs:label>
#         <dracon:is_author_of rdf:resource="https://dracor.org/entity/ger000006"/>
#         <owl:sameAs rdf:resource="http://www.wikidata.org/entity/Q76755"/>
#         <owl:sameAs rdf:resource="https://d-nb.info/gnd/118543830"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755/appellation/name">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Gutzkow, Karl [appellation; name]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/name"/>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/Q76755"/>
#         <rdf:value>Gutzkow, Karl</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/Q76755/appellation/name"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755/appellation/fullname">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Karl Gutzkow [appellation; fullname]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/fullname"/>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/Q76755"/>
#         <rdf:value>Karl Gutzkow</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/Q76755/appellation/fullname"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755/appellation/shortname">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Gutzkow [appellation; shortname]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/shortname"/>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/Q76755"/>
#         <rdf:value>Gutzkow</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/Q76755/appellation/shortname"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755/id/wikidata">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E42_Identifier"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/id/wikidata"/>
#         <rdfs:label>Wikidata Identifier of Gutzkow, Karl</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/Q76755"/>
#         <rdf:value>Q76755</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/Q76755/id/wikidata"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0">
#         <crm:P14_carried_out_by rdf:resource="https://dracor.org/entity/Q76755"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/Q76755">
#         <crm:P14i_performed rdf:resource="https://dracor.org/entity/ger000006/creation/0"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:averageClustering rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.787224283652855</dracon:averageClustering>
#         <dracon:averagePathLength rdf:datatype="http://www.w3.org/2001/XMLSchema#float">1.9153439153439153</dracon:averagePathLength>
#         <dracon:averageDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#float">8.142857142857142</dracon:averageDegree>
#         <dracon:density rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.30158730158730157</dracon:density>
#         <dracon:diameter rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">4</dracon:diameter>
#         <dracon:maxDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">22</dracon:maxDegree>
#         <dracon:networkSize rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">28</dracon:networkSize>
#         <dracon:numConnectedComponents rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:numConnectedComponents>
#         <dracon:wikipediaLinkCount rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">0</dracon:wikipediaLinkCount>
#         <dracon:maxDegreeCharacter rdf:resource="https://dracor.org/entity/ger000006/character/savage"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/neunte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/oberrichter">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.07868892544497513</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_tyrconnel">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">21</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.6</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.14868464130991219</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.1490247644093798</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/vierte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/fuenfte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/viscount">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">12</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.54</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.11081948504294756</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.006059609905763752</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/bursche">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.35064935064935066</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.012369415693718957</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/sechste_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/haushofmeister">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.38028169014084506</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.014415686081413288</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/toms">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">9</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5192307692307693</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.06695683201238202</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.03561253561253561</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/zweiter_bedienter">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.38571428571428573</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.015131464848361604</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/dritte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/zweite_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/maennliche_stimme">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.42857142857142855</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.07101924648499286</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/zehnte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/savage">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">22</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">42</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.84375</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.36774650723014357</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.4117795310103001</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_winchester">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">24</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.6</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.16355239098708776</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.01931843085689238</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/steele">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">17</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">28</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.7105263157894737</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.3354755732802925</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.14617576156037693</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/miss_ellen">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">22</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.6</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.15606685671075454</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.08797939951786106</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/erster_bedienter">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.38571428571428573</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.015131464848361604</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_berwick">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">24</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.6</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.16355239098708776</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.01931843085689238</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lady">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">12</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">29</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.6428571428571429</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.17487586903607158</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.0663269778654394</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/erste_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/bedienter_der_lady">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">9</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.54</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.10294096333105837</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.008547008547008548</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/achte_maske">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5510204081632653</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.24881260968181157</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/kitty">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">9</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5192307692307693</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.06695683201238202</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.03561253561253561</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/alle_4-2-4">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.5625</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.13947190435889914</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/dritter_bedienter">
#         <dracon:degree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:degree>
#         <dracon:weightedDegree rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:weightedDegree>
#         <dracon:closeness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.46551724137931033</dracon:closeness>
#         <dracon:eigenvector rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0.033967987233759836</dracon:eigenvector>
#         <dracon:betweenness rdf:datatype="http://www.w3.org/2001/XMLSchema#float">0</dracon:betweenness>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/miss_ellen">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Miss Ellen [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/miss_ellen/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/female"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2045</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">55</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/miss_ellen"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/miss_ellen/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Miss Ellen [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/miss_ellen"/>
#         <rdf:value>Miss Ellen</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/steele">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Steele [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/steele/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3329</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">58</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">9</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/steele"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/steele/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Steele [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/steele"/>
#         <rdf:value>Steele</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/savage">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Savage [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/savage/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5077</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">99</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">18</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/savage"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/savage/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Savage [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/savage"/>
#         <rdf:value>Savage</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/viscount">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Viscount [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/viscount/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">755</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">25</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/viscount"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/viscount/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Viscount [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/viscount"/>
#         <rdf:value>Viscount</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_winchester">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Lord Winchester [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/lord_winchester/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">354</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">22</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">6</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/lord_winchester"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_winchester/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Lord Winchester [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/lord_winchester"/>
#         <rdf:value>Lord Winchester</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lady">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Lady [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/lady/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/female"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2373</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">81</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">9</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/lady"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lady/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Lady [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/lady"/>
#         <rdf:value>Lady</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_berwick">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Lord Berwick [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/lord_berwick/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">341</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">24</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">6</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/lord_berwick"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_berwick/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Lord Berwick [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/lord_berwick"/>
#         <rdf:value>Lord Berwick</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/bedienter_der_lady">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Bedienter der Lady [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/bedienter_der_lady/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">150</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">14</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">3</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/bedienter_der_lady"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/bedienter_der_lady/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Bedienter der Lady [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/bedienter_der_lady"/>
#         <rdf:value>Bedienter der Lady</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_tyrconnel">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Lord Tyrconnel [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/lord_tyrconnel/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2157</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">48</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/lord_tyrconnel"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/lord_tyrconnel/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Lord Tyrconnel [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/lord_tyrconnel"/>
#         <rdf:value>Lord Tyrconnel</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/maennliche_stimme">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Männliche Stimme (Schauspieler) [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/maennliche_stimme/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">14</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/maennliche_stimme"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/maennliche_stimme/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Männliche Stimme (Schauspieler) [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/maennliche_stimme"/>
#         <rdf:value>Männliche Stimme (Schauspieler)</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/haushofmeister">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Haushofmeister [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/haushofmeister/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">121</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/haushofmeister"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/haushofmeister/appellation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <rdfs:label>Haushofmeister [appellation of character]</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/character/haushofmeister"/>
#         <rdf:value>Haushofmeister</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/oberrichter">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F38_Character"/>
#         <rdf:type rdf:resource="http://dracor.org/ontology#character"/>
#         <rdfs:label>Oberrichter [Character in 'Richard Savage oder Der Sohn einer Mutter']</rdfs:label>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/character/oberrichter/appellation/1"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/gender/male"/>
#         <dracon:speaks_numOfWords rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">168</dracon:speaks_numOfWords>
#         <dracon:has_numOfSpeechActs rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">4</dracon:has_numOfSpeechActs>
#         <dracon:in_numOfScenes rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1</dracon:in_numOfScenes>
#         <dracon:is_character_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <dracon:has_character rdf:resource="https://dracor.org/entity/ger000006/character/oberrichter"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/character/oberrichter/appellation/1">
# ...
#         <crm:P86i_contains rdf:resource="https://dracor.org/entity/ger000006/performance/premiere/ts"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/performance/premiere/ts">
#         <crm:P86_falls_within rdf:resource="https://dracor.org/entity/date/1839"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/work">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F14_Individual_Work"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Work]</rdfs:label>
#         <frbroo:R40_has_representative_expression rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <frbroo:R9_is_realised_in rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <frbroo:R9_is_realised_in rdf:resource="https://dracor.org/entity/ger000006/expression/1"/>
#         <frbroo:R19i_was_realised_through rdf:resource="https://dracor.org/entity/ger000006/creation/0"/>
#         <owl:sameAs rdf:resource="http://www.wikidata.org/entity/Q56254719"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/expression/2">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F22_Self-Contained_Expression"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Expression]</rdfs:label>
#         <crm:P3_has_note>The text of 'Richard Savage oder Der Sohn einer Mutter' as found in the edition: Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].</crm:P3_has_note>
#         <frbroo:R40i_is_representative_expression_for rdf:resource="https://dracor.org/entity/ger000006/work"/>
#         <frbroo:R9i_realises rdf:resource="https://dracor.org/entity/ger000006/work"/>
#         <frbroo:R4_carriers_provided_by rdf:resource="https://dracor.org/entity/ger000006/manifestation/2"/>
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006/publication-expression/2"/>
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006">
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/manifestation/2">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F3_Manifestation_Product_Type"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Manifestation]</rdfs:label>
#         <crm:P3_has_note>The publication product containing the edition of the text 'Richard Savage oder Der Sohn einer Mutter', published as: Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].</crm:P3_has_note>
#         <frbroo:R4i_comprises_carriers_of rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <frbroo:CLR6_should_carry rdf:resource="https://dracor.org/entity/ger000006/publication-expression/2"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication-expression/2">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F24_Publication_Expression"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Publication Expression]</rdfs:label>
#         <crm:P3_has_note>The text 'Richard Savage oder Der Sohn einer Mutter', its layout and the textual and graphic content of front and back
# cover, spine of the publication Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].</crm:P3_has_note>
#         <frbroo:CLR6i_should_be_carried_by rdf:resource="https://dracor.org/entity/ger000006/manifestation/2"/>
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <frbroo:R24i_was_created_through rdf:resource="https://dracor.org/entity/ger000006/publication/2"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication/2">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F30_Publication_Event"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Publication Event]</rdfs:label>
#         <crm:P3_has_note>Publishing of 'Richard Savage oder Der Sohn einer Mutter' in the publication Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].</crm:P3_has_note>
#         <frbroo:R24_created rdf:resource="https://dracor.org/entity/ger000006/publication-expression/2"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication/1">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F30_Publication_Event"/>
#         <rdfs:label>First Publication of 'Richard Savage oder Der Sohn einer Mutter' [Publication Event]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/activity/publishing/first-time"/>
#         <crm:P4_has_time-span rdf:resource="https://dracor.org/entity/ger000006/publication/1/ts"/>
#         <frbroo:R24_created rdf:resource="https://dracor.org/entity/ger000006/publication-expression/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication/1/ts">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E52_Time-Span"/>
#         <crm:P3_has_note>dated: 1842</crm:P3_has_note>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/date/first-publication"/>
#         <rdfs:label>Date of first Publication of 'Richard Savage oder Der Sohn einer Mutter' [Time-span]</rdfs:label>
#         <crm:P4i_is_time-span_of rdf:resource="https://dracor.org/entity/ger000006/publication/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/date/1842">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E52_Time-Span"/>
#         <rdfs:label>1842 [Year]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/date/year"/>
#         <crm:P86i_contains rdf:resource="https://dracor.org/entity/ger000006/publication/1/ts"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication/1/ts">
#         <crm:P86_falls_within rdf:resource="https://dracor.org/entity/date/1842"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/publication-expression/1">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F24_Publication_Expression"/>
#         <rdfs:label>First Publication of 'Richard Savage oder Der Sohn einer Mutter' [Publication Expression]</rdfs:label>
#         <crm:P3_has_note>The text 'Richard Savage oder Der Sohn einer Mutter', its layout and the textual and graphic content of the first publication.</crm:P3_has_note>
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/1"/>
#         <frbroo:R24i_was_created_through rdf:resource="https://dracor.org/entity/ger000006/publication/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/expression/1">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F22_Self-Contained_Expression"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [Text of first publication; Expression]</rdfs:label>
#         <crm:P3_has_note>The text of 'Richard Savage oder Der Sohn einer Mutter' as found in its first publication.</crm:P3_has_note>
#         <frbroo:R9i_realises rdf:resource="https://dracor.org/entity/ger000006/work"/>
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006/publication-expression/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0">
#         <rdf:type rdf:resource="http://iflastandards.info/ns/fr/frbr/frbroo/F28_Expression_Creation"/>
#         <rdfs:label>Writing of 'Richard Savage oder Der Sohn einer Mutter', until it was first published.</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/activity/writing"/>
#         <frbroo:R19_created_a_realization_of rdf:resource="https://dracor.org/entity/ger000006/work"/>
#         <crm:P4_has_time-span rdf:resource="https://dracor.org/entity/ger000006/creation/0/ts"/>
#         <crm:P134i_was_continued_by rdf:resource="https://dracor.org/entity/ger000006/creation/0/end"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0/ts">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E52_Time-Span"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/date/writing"/>
#         <rdfs:label>Time-span, in which 'Richard Savage oder Der Sohn einer Mutter' was written until it was considered ready to be published for the first time.</rdfs:label>
#         <crm:P4i_is_time-span_of rdf:resource="https://dracor.org/entity/ger000006/creation/0"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0/end">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E7_Activity"/>
#         <rdfs:label>Finishing writing 'Richard Savage oder Der Sohn einer Mutter', resulting in the text being ready for it's first publication.</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/activity/finishing"/>
#         <crm:P134_continued rdf:resource="https://dracor.org/entity/ger000006/creation/0"/>
#         <crm:P4_has_time-span rdf:resource="https://dracor.org/entity/ger000006/creation/0/end/ts"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0/end/ts">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E52_Time-Span"/>
#         <rdfs:label>Time-span, in which writing 'Richard Savage oder Der Sohn einer Mutter' was finished, resulting in the text being ready for its first publication.</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/date/finishing"/>
#         <crm:P3_has_note>dated: 1839</crm:P3_has_note>
#         <crm:P4i_is_time-span_of rdf:resource="https://dracor.org/entity/ger000006/creation/0/end"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/date/1839">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E52_Time-Span"/>
#         <rdfs:label>1839 [Year]</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/date/year"/>
#         <crm:P86i_contains rdf:resource="https://dracor.org/entity/ger000006/creation/0/end/ts"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/creation/0/end/ts">
#         <crm:P86_falls_within rdf:resource="https://dracor.org/entity/date/1839"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/digitalsource/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E73_Information_Object"/>
#         <rdfs:label>Digital Source of 'Richard Savage oder Der Sohn einer Mutter'</rdfs:label>
#         <crm:P3_has_note>Provenance of file: TextGrid Repository</crm:P3_has_note>
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <rdfs:seeAlso rdf:resource="http://www.textgridrep.org/textgrid:p5c8.0"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/expression/2">
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006/digitalsource/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/digitalsource/1/id/url/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E42_Identifier"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/id/url"/>
#         <rdfs:label>Url of the digital source of play 'Richard Savage oder Der Sohn einer Mutter'</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/ger000006/digitalsource/1"/>
#         <rdf:value>http://www.textgridrep.org/textgrid:p5c8.0</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/digitalsource/1">
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/ger000006/digitalsource/1/id/url/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/file/tei/in/preparation/1">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E11_Modification"/>
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E65_Creation"/>
#         <rdfs:label>Preparation of TEI-File 'Richard Savage oder Der Sohn einer Mutter'</rdfs:label>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/activity/editing"/>
#         <crm:P16_used_specific_object rdf:resource="https://dracor.org/entity/ger000006/digitalsource/1"/>
#         <crm:P94_has_created rdf:resource="https://dracor.org/entity/ger000006/file/tei/in"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/type/activity/editing">
#         <crm:P2i_is_type_of rdf:resource="https://dracor.org/entity/ger000006/file/tei/in/preparation/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/digitalsource/1">
#         <crm:P16i_was_used_for rdf:resource="https://dracor.org/entity/ger000006/file/tei/in/preparation/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/file/tei/in">
#         <crm:P94i_was_created_by rdf:resource="https://dracor.org/entity/ger000006/file/tei/in/preparation/1"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/file/tei/out">
#         <rdf:type rdf:resource="http://www.ics.forth.gr/isl/CRMdig/D1_Digital_Object"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [TEI; API Output]</rdfs:label>
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#         <crm:P190_has_symbolic_content rdf:resource="https://dracor.org/api/corpora/ger/play/gutzkow-richard-savage/tei"/>
#         <rdfs:seeAlso rdf:resource="https://dracor.org/api/corpora/ger/play/gutzkow-richard-savage/tei"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/file/tei/in">
#         <rdf:type rdf:resource="http://www.ics.forth.gr/isl/CRMdig/D1_Digital_Object"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/file/dracor-tei-source"/>
#         <rdfs:label>Richard Savage oder Der Sohn einer Mutter [TEI-File that was ingested into the DraCor-Platform]</rdfs:label>
#         <crm:P165_incorporates rdf:resource="https://dracor.org/entity/ger000006/expression/2"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/ger000006/expression/2">
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006/file/tei/out"/>
#         <crm:P165i_is_incorporated_in rdf:resource="https://dracor.org/entity/ger000006/file/tei/in"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/type/file/dracor-tei-source">
#         <crm:P2i_is_type_of rdf:resource="https://dracor.org/entity/ger000006/file/tei/in"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/ger">
#         <crm:P148_has_component rdf:resource="https://dracor.org/entity/ger000006"/>
#     </rdf:Description>
# </rdf:RDF>

# %% [markdown]
# We implement a function, to get the rdf, parse it and store it locally using the package rdflib.

# %%
import rdflib
from rdflib import Namespace, URIRef, RDF, RDFS, Literal, Graph, XSD

# %%
#setup rdf creation
# CIDOC – used: CIDOC CRM v7.1.1 (draft) implemented in RDFS
cidoc_ns = "http://www.cidoc-crm.org/cidoc-crm/"
CRM = Namespace(cidoc_ns)
#FRBRoo – used: FRBRoo v2.4 DRAFT harmonised with CIDOC CRM v6.2.1 encoded in RDFS
frbroo_ns = "http://iflastandards.info/ns/fr/frbr/frbroo/"
FRBROO = Namespace(frbroo_ns)
#OWL
owl_ns = "http://www.w3.org/2002/07/owl#"
# CLS Infra CIDOC CRM Extension
crmcls_ns = "https://clsinfra.io/ontologies/CRMcls/"
CRMCLS = Namespace(crmcls_ns)

# %%
def add_ns(graph):
    graph.namespace_manager.bind('crm', URIRef(cidoc_ns))
    #graph.namespace_manager.bind('crmdig', URIRef(crmdig_ns))
    graph.namespace_manager.bind('frbroo', URIRef(frbroo_ns))
    graph.namespace_manager.bind('crmcls', URIRef(crmcls_ns))
    graph.namespace_manager.bind('owl', URIRef(owl_ns))
    return graph

# %%
def get_rdf(corpusname:str, playname:str):
    # get the data from endpoint using the generic get function
    data = get(method=method, playname=playname, corpusname=corpusname, parse_json=False, apibase="http://localhost:8080/exist/restxq/")
    
    #parse the rdf
    g = rdflib.Graph().parse(data=data, format='xml')
    g = add_ns(g)
    #print(g.serialize(format="ttl").decode("utf-8"))
    return g

# %%
get_rdf(corpusname, playname)
# Out:
# @prefix crm: <http://www.cidoc-crm.org/cidoc-crm/> .
# @prefix crmcls: <https://clsinfra.io/ontologies/CRMcls/> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dracon: <http://dracor.org/ontology#> .
# @prefix frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://www.wikidata.org/entity/Q80930> crm:P136i_supported_type_creation <https://dracor.org/entity/activity/type_creation/Q80930> .
#
# <https://dracor.org/entity/Q76755/appellation/fullname> a crm:E41_Appellation ;
#     rdfs:label "Karl Gutzkow [appellation; fullname]" ;
#     crm:P1i_identifies <https://dracor.org/entity/Q76755> ;
#     crm:P2_has_type <https://dracor.org/entity/type/fullname> ;
#     rdf:value "Karl Gutzkow" .
#
# <https://dracor.org/entity/Q76755/appellation/name> a crm:E41_Appellation ;
#     rdfs:label "Gutzkow, Karl [appellation; name]" ;
#     crm:P1i_identifies <https://dracor.org/entity/Q76755> ;
#     crm:P2_has_type <https://dracor.org/entity/type/name> ;
#     rdf:value "Gutzkow, Karl" .
#
# <https://dracor.org/entity/Q76755/appellation/shortname> a crm:E41_Appellation ;
#     rdfs:label "Gutzkow [appellation; shortname]" ;
#     crm:P1i_identifies <https://dracor.org/entity/Q76755> ;
#     crm:P2_has_type <https://dracor.org/entity/type/shortname> ;
#     rdf:value "Gutzkow" .
#
# <https://dracor.org/entity/Q76755/id/wikidata> a crm:E42_Identifier ;
#     rdfs:label "Wikidata Identifier of Gutzkow, Karl" ;
#     crm:P1i_identifies <https://dracor.org/entity/Q76755> ;
#     crm:P2_has_type <https://dracor.org/entity/type/id/wikidata> ;
#     rdf:value "Q76755" .
#
# <https://dracor.org/entity/date/1842> a crm:E52_Time-Span ;
#     rdfs:label "1842 [Year]" ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/year> ;
#     crm:P86i_contains <https://dracor.org/entity/ger000006/publication/1/ts> .
#
# <https://dracor.org/entity/ger000006/character/achte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Achte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/achte_maske> ;
#     rdf:value "Achte Maske" .
#
# <https://dracor.org/entity/ger000006/character/alle_4-2-4/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Alle (IV/2/4) [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/alle_4-2-4> ;
#     rdf:value "Alle (IV/2/4)" .
#
# <https://dracor.org/entity/ger000006/character/bedienter_der_lady/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Bedienter der Lady [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/bedienter_der_lady> ;
#     rdf:value "Bedienter der Lady" .
#
# <https://dracor.org/entity/ger000006/character/bursche/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Bursche [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/bursche> ;
#     rdf:value "Bursche" .
#
# <https://dracor.org/entity/ger000006/character/dritte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Dritte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/dritte_maske> ;
#     rdf:value "Dritte Maske" .
#
# <https://dracor.org/entity/ger000006/character/dritter_bedienter/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Dritter Bedienter [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/dritter_bedienter> ;
#     rdf:value "Dritter Bedienter" .
#
# <https://dracor.org/entity/ger000006/character/erste_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Erste Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/erste_maske> ;
#     rdf:value "Erste Maske" .
#
# <https://dracor.org/entity/ger000006/character/erster_bedienter/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Erster Bedienter [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/erster_bedienter> ;
#     rdf:value "Erster Bedienter" .
#
# <https://dracor.org/entity/ger000006/character/fuenfte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Fünfte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/fuenfte_maske> ;
#     rdf:value "Fünfte Maske" .
#
# <https://dracor.org/entity/ger000006/character/haushofmeister/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Haushofmeister [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/haushofmeister> ;
#     rdf:value "Haushofmeister" .
#
# <https://dracor.org/entity/ger000006/character/kitty/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Kitty [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/kitty> ;
#     rdf:value "Kitty" .
#
# <https://dracor.org/entity/ger000006/character/lady/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Lady [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/lady> ;
#     rdf:value "Lady" .
#
# <https://dracor.org/entity/ger000006/character/lord_berwick/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Lord Berwick [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/lord_berwick> ;
#     rdf:value "Lord Berwick" .
#
# <https://dracor.org/entity/ger000006/character/lord_tyrconnel/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Lord Tyrconnel [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/lord_tyrconnel> ;
#     rdf:value "Lord Tyrconnel" .
#
# <https://dracor.org/entity/ger000006/character/lord_winchester/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Lord Winchester [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/lord_winchester> ;
#     rdf:value "Lord Winchester" .
#
# <https://dracor.org/entity/ger000006/character/maennliche_stimme/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Männliche Stimme (Schauspieler) [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/maennliche_stimme> ;
#     rdf:value "Männliche Stimme (Schauspieler)" .
#
# <https://dracor.org/entity/ger000006/character/miss_ellen/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Miss Ellen [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/miss_ellen> ;
#     rdf:value "Miss Ellen" .
#
# <https://dracor.org/entity/ger000006/character/neunte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Neunte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/neunte_maske> ;
#     rdf:value "Neunte Maske" .
#
# <https://dracor.org/entity/ger000006/character/oberrichter/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Oberrichter [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/oberrichter> ;
#     rdf:value "Oberrichter" .
#
# <https://dracor.org/entity/ger000006/character/savage/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Savage [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/savage> ;
#     rdf:value "Savage" .
#
# <https://dracor.org/entity/ger000006/character/sechste_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Sechste Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/sechste_maske> ;
#     rdf:value "Sechste Maske" .
#
# <https://dracor.org/entity/ger000006/character/steele/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Steele [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/steele> ;
#     rdf:value "Steele" .
#
# <https://dracor.org/entity/ger000006/character/toms/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Toms [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/toms> ;
#     rdf:value "Toms" .
#
# <https://dracor.org/entity/ger000006/character/vierte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Vierte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/vierte_maske> ;
#     rdf:value "Vierte Maske" .
#
# <https://dracor.org/entity/ger000006/character/viscount/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Viscount [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/viscount> ;
#     rdf:value "Viscount" .
#
# <https://dracor.org/entity/ger000006/character/zehnte_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Zehnte Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/zehnte_maske> ;
#     rdf:value "Zehnte Maske" .
#
# <https://dracor.org/entity/ger000006/character/zweite_maske/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Zweite Maske [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/zweite_maske> ;
#     rdf:value "Zweite Maske" .
#
# <https://dracor.org/entity/ger000006/character/zweiter_bedienter/appellation/1> a crm:E41_Appellation ;
#     rdfs:label "Zweiter Bedienter [appellation of character]" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/character/zweiter_bedienter> ;
#     rdf:value "Zweiter Bedienter" .
#
# <https://dracor.org/entity/ger000006/creation/0/ts> a crm:E52_Time-Span ;
#     rdfs:label "Time-span, in which 'Richard Savage oder Der Sohn einer Mutter' was written until it was considered ready to be published for the first time." ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/writing> ;
#     crm:P4i_is_time-span_of <https://dracor.org/entity/ger000006/creation/0> .
#
# <https://dracor.org/entity/ger000006/digitalsource/1/id/url/1> a crm:E42_Identifier ;
#     rdfs:label "Url of the digital source of play 'Richard Savage oder Der Sohn einer Mutter'" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006/digitalsource/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/id/url> ;
#     rdf:value "http://www.textgridrep.org/textgrid:p5c8.0" .
#
# <https://dracor.org/entity/ger000006/file/tei/out> a <http://www.ics.forth.gr/isl/CRMdig/D1_Digital_Object> ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [TEI; API Output]" ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P190_has_symbolic_content <https://dracor.org/api/corpora/ger/play/gutzkow-richard-savage/tei> ;
#     rdfs:seeAlso <https://dracor.org/api/corpora/ger/play/gutzkow-richard-savage/tei> .
#
# <https://dracor.org/entity/ger000006/id/dracor> a crm:E42_Identifier ;
#     rdfs:label "DraCor Identifier of play 'Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen'" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/id/dracor> ;
#     rdf:value "ger000006" .
#
# <https://dracor.org/entity/ger000006/id/playname> a crm:E42_Identifier ;
#     rdfs:label "DraCor Identifier 'playname' of play 'Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen'" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/id/playname> ;
#     rdf:value "gutzkow-richard-savage" .
#
# <https://dracor.org/entity/ger000006/id/wikidata> a crm:E42_Identifier ;
#     rdfs:label "Wikidata Identifier of play 'Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen'" ;
#     crm:P1i_identifies <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/id/wikidata> ;
#     rdf:value "Q56254719" .
#
# <https://dracor.org/entity/ger000006/publication/2> a frbroo:F30_Publication_Event ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [Publication Event]" ;
#     frbroo:R24_created <https://dracor.org/entity/ger000006/publication-expression/2> ;
#     crm:P3_has_note "Publishing of 'Richard Savage oder Der Sohn einer Mutter' in the publication Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912]." .
#
# <https://dracor.org/entity/ger000006/title/main/ger> a crm:E35_Title ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [main title]" ;
#     crm:P102i_is_title_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/title/main> ;
#     crm:P72_has_language <https://dracor.org/entity/language/ger> ;
#     rdf:value "Richard Savage oder Der Sohn einer Mutter" .
#
# <https://dracor.org/entity/ger000006/title/sub/ger> a crm:E35_Title ;
#     rdfs:label "Trauerspiel in fünf Aufzügen [subtitle]" ;
#     crm:P102i_is_title_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/title/sub> ;
#     crm:P72_has_language <https://dracor.org/entity/language/ger> ;
#     rdf:value "Trauerspiel in fünf Aufzügen" .
#
# <https://dracor.org/entity/type/activity/editing> crm:P2i_is_type_of <https://dracor.org/entity/ger000006/file/tei/in/preparation/1> .
#
# <https://dracor.org/entity/type/file/dracor-tei-source> crm:P2i_is_type_of <https://dracor.org/entity/ger000006/file/tei/in> .
#
# <https://dracor.org/entity/activity/classification/86ae93a3fddf1524715ebd4e915f4ee3> a crm:E17_Type_Assignment ;
#     rdfs:label "Assigning of Genre Type 'Tragedy' to Play 'https://dracor.org/entity/ger000006'" ;
#     crm:P2_has_type <https://dracor.org/entity/type/classification/genre> ;
#     crm:P41_classified <https://dracor.org/entity/ger000006> ;
#     crm:P42_assigned <https://dracor.org/entity/type/genre/tragedy> .
#
# <https://dracor.org/entity/activity/type_creation/Q80930> a crm:E83_Type_Creation ;
#     rdfs:label "Creation of Genre Type 'Tragedy' based on Wikidata-Entity 'Q80930'" ;
#     crm:P135_created_type <https://dracor.org/entity/type/genre/tragedy> ;
#     crm:P136_was_based_on <http://www.wikidata.org/entity/Q80930> .
#
# <https://dracor.org/entity/corpus/ger> crm:P148_has_component <https://dracor.org/entity/ger000006> .
#
# <https://dracor.org/entity/date/1839> a crm:E52_Time-Span ;
#     rdfs:label "1839 [Year]" ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/year> ;
#     crm:P86i_contains <https://dracor.org/entity/ger000006/creation/0/end/ts>,
#         <https://dracor.org/entity/ger000006/performance/premiere/ts> .
#
# <https://dracor.org/entity/ger000006/creation/0/end> a crm:E7_Activity ;
#     rdfs:label "Finishing writing 'Richard Savage oder Der Sohn einer Mutter', resulting in the text being ready for it's first publication." ;
#     crm:P134_continued <https://dracor.org/entity/ger000006/creation/0> ;
#     crm:P2_has_type <https://dracor.org/entity/type/activity/finishing> ;
#     crm:P4_has_time-span <https://dracor.org/entity/ger000006/creation/0/end/ts> .
#
# <https://dracor.org/entity/ger000006/creation/0/end/ts> a crm:E52_Time-Span ;
#     rdfs:label "Time-span, in which writing 'Richard Savage oder Der Sohn einer Mutter' was finished, resulting in the text being ready for its first publication." ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/finishing> ;
#     crm:P3_has_note "dated: 1839" ;
#     crm:P4i_is_time-span_of <https://dracor.org/entity/ger000006/creation/0/end> ;
#     crm:P86_falls_within <https://dracor.org/entity/date/1839> .
#
# <https://dracor.org/entity/ger000006/expression/1> a frbroo:F22_Self-Contained_Expression ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [Text of first publication; Expression]" ;
#     frbroo:R9i_realises <https://dracor.org/entity/ger000006/work> ;
#     crm:P165i_is_incorporated_in <https://dracor.org/entity/ger000006/publication-expression/1> ;
#     crm:P3_has_note "The text of 'Richard Savage oder Der Sohn einer Mutter' as found in its first publication." .
#
# <https://dracor.org/entity/ger000006/manifestation/2> a frbroo:F3_Manifestation_Product_Type ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [Manifestation]" ;
#     frbroo:CLR6_should_carry <https://dracor.org/entity/ger000006/publication-expression/2> ;
#     frbroo:R4i_comprises_carriers_of <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P3_has_note "The publication product containing the edition of the text 'Richard Savage oder Der Sohn einer Mutter', published as: Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912]." .
#
# <https://dracor.org/entity/ger000006/performance/premiere> a frbroo:F31_Performance ;
#     rdfs:label "Premiere of Gutzkow, Karl: Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen" ;
#     frbroo:R66_included_performed_version_of <https://dracor.org/entity/ger000006/work> ;
#     crm:P2_has_type <https://dracor.org/entity/type/performance/premiere> ;
#     crm:P4_has_time-span <https://dracor.org/entity/ger000006/performance/premiere/ts> .
#
# <https://dracor.org/entity/ger000006/performance/premiere/ts> a crm:E52_Time-Span ;
#     rdfs:label "Premiere of Gutzkow, Karl: Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen [Time-span]" ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/premiere> ;
#     crm:P3_has_note "dated: 1839" ;
#     crm:P4i_is_time-span_of <https://dracor.org/entity/ger000006/performance/premiere> ;
#     crm:P86_falls_within <https://dracor.org/entity/date/1839> .
#
# <https://dracor.org/entity/ger000006/publication-expression/1> a frbroo:F24_Publication_Expression ;
#     rdfs:label "First Publication of 'Richard Savage oder Der Sohn einer Mutter' [Publication Expression]" ;
#     frbroo:R24i_was_created_through <https://dracor.org/entity/ger000006/publication/1> ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/1> ;
#     crm:P3_has_note "The text 'Richard Savage oder Der Sohn einer Mutter', its layout and the textual and graphic content of the first publication." .
#
# <https://dracor.org/entity/ger000006/publication/1> a frbroo:F30_Publication_Event ;
#     rdfs:label "First Publication of 'Richard Savage oder Der Sohn einer Mutter' [Publication Event]" ;
#     frbroo:R24_created <https://dracor.org/entity/ger000006/publication-expression/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/activity/publishing/first-time> ;
#     crm:P4_has_time-span <https://dracor.org/entity/ger000006/publication/1/ts> .
#
# <https://dracor.org/entity/ger000006/publication/1/ts> a crm:E52_Time-Span ;
#     rdfs:label "Date of first Publication of 'Richard Savage oder Der Sohn einer Mutter' [Time-span]" ;
#     crm:P2_has_type <https://dracor.org/entity/type/date/first-publication> ;
#     crm:P3_has_note "dated: 1842" ;
#     crm:P4i_is_time-span_of <https://dracor.org/entity/ger000006/publication/1> ;
#     crm:P86_falls_within <https://dracor.org/entity/date/1842> .
#
# <https://dracor.org/entity/relation/073f108617fcca3e5033885202fce7af> a dracon:relation ;
#     rdfs:label "bedienter_der_lady is associated with lady" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_associated_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/bedienter_der_lady> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/lady> .
#
# <https://dracor.org/entity/relation/0d159dfb6df55edf7994124bfb67297c> a dracon:relation ;
#     rdfs:label "haushofmeister is associated with lady" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_associated_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/haushofmeister> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/lady> .
#
# <https://dracor.org/entity/relation/3bd4694cd199a2a4a8f1217d28ae8940> a dracon:relation ;
#     rdfs:label "steele has friend savage" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/has_friend> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/steele> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/savage> .
#
# <https://dracor.org/entity/relation/535e050ffd55b85d5778a4e58705908a> a dracon:relation ;
#     rdfs:label "lady is associated with haushofmeister" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_associated_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/lady> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/haushofmeister> .
#
# <https://dracor.org/entity/relation/5456c69811e39cf3693e24e6afc90846> a dracon:relation ;
#     rdfs:label "kitty has spouse toms" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/has_spouse> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/kitty> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/toms> .
#
# <https://dracor.org/entity/relation/75fdbd6b4a662a2535669af59543d3e8> a dracon:relation ;
#     rdfs:label "viscount is related with lady" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_related_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/viscount> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/lady> .
#
# <https://dracor.org/entity/relation/7aba7b7dc35696fa54d2d19e3ec1c1eb> a dracon:relation ;
#     rdfs:label "savage is friend of steele" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_friend_of> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/savage> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/steele> .
#
# <https://dracor.org/entity/relation/a71a6c3f6cce5baf315f852e8ebc64db> a dracon:relation ;
#     rdfs:label "savage has friend steele" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/has_friend> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/savage> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/steele> .
#
# <https://dracor.org/entity/relation/c754f20173046d0165bcfc1ca9186b1c> a dracon:relation ;
#     rdfs:label "toms has spouse kitty" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/has_spouse> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/toms> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/kitty> .
#
# <https://dracor.org/entity/relation/c99777d668157d28934d6210fd8ecb88> a dracon:relation ;
#     rdfs:label "lady is associated with bedienter_der_lady" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_associated_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/lady> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/bedienter_der_lady> .
#
# <https://dracor.org/entity/relation/cd7b7c28df1e00349f2c434069182c28> a dracon:relation ;
#     rdfs:label "lady is related with viscount" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_related_with> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/lady> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/viscount> .
#
# <https://dracor.org/entity/relation/d08c4c94a4e4825ec09fd3384039d1b7> a dracon:relation ;
#     rdfs:label "toms is spouse of kitty" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_spouse_of> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/toms> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/kitty> .
#
# <https://dracor.org/entity/relation/f32fa05a47a5b0e7b79c047783d3dab9> a dracon:relation ;
#     rdfs:label "steele is friend of savage" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_friend_of> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/steele> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/savage> .
#
# <https://dracor.org/entity/relation/fbb022e635984407581f445d59e9c60a> a dracon:relation ;
#     rdfs:label "kitty is spouse of toms" ;
#     dracon:has_relation_type <https://dracor.org/entity/type/relation/is_spouse_of> ;
#     crm:P01_has_domain <https://dracor.org/entity/ger000006/character/kitty> ;
#     crm:P02_has_range <https://dracor.org/entity/ger000006/character/toms> .
#
# <https://dracor.org/entity/type/genre/tragedy> a crm:E55_Type ;
#     rdfs:label "Tragedy [Genre]" ;
#     crm:P135i_was_created_by <https://dracor.org/entity/activity/type_creation/Q80930> ;
#     crm:P2_has_type <https://dracor.org/entity/type/genre> ;
#     crm:P42i_was_assigned_by <https://dracor.org/entity/activity/classification/86ae93a3fddf1524715ebd4e915f4ee3> .
#
# <https://dracor.org/entity/ger000006/character/achte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Achte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 1 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/achte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/alle_4-2-4> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Alle (IV/2/4) [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/25> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5625"^^xsd:float ;
#     dracon:degree 7 ;
#     dracon:eigenvector "0.13947190435889914"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 2 ;
#     dracon:weightedDegree 7 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/alle_4-2-4/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/unknown>,
#         <https://dracor.org/entity/type/group> .
#
# <https://dracor.org/entity/ger000006/character/bursche> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Bursche [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/27> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.35064935064935066"^^xsd:float ;
#     dracon:degree 2 ;
#     dracon:eigenvector "0.012369415693718957"^^xsd:float ;
#     dracon:has_numOfSpeechActs 3 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 45 ;
#     dracon:weightedDegree 2 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/bursche/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/dritte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Dritte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 12 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/dritte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/dritter_bedienter> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Dritter Bedienter [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/21> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.46551724137931033"^^xsd:float ;
#     dracon:degree 1 ;
#     dracon:eigenvector "0.033967987233759836"^^xsd:float ;
#     dracon:has_numOfSpeechActs 2 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 99 ;
#     dracon:weightedDegree 1 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/dritter_bedienter/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/erste_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Erste Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 4 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/erste_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/erster_bedienter> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Erster Bedienter [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/19> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.38571428571428573"^^xsd:float ;
#     dracon:degree 2 ;
#     dracon:eigenvector "0.015131464848361604"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 11 ;
#     dracon:weightedDegree 2 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/erster_bedienter/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/fuenfte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Fünfte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 1 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/fuenfte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/maennliche_stimme> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Männliche Stimme (Schauspieler) [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/11> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.42857142857142855"^^xsd:float ;
#     dracon:degree 5 ;
#     dracon:eigenvector "0.07101924648499286"^^xsd:float ;
#     dracon:has_numOfSpeechActs 2 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 14 ;
#     dracon:weightedDegree 5 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/maennliche_stimme/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/neunte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Neunte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 2 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/neunte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/oberrichter> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Oberrichter [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/17> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5"^^xsd:float ;
#     dracon:degree 3 ;
#     dracon:eigenvector "0.07868892544497513"^^xsd:float ;
#     dracon:has_numOfSpeechActs 4 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 168 ;
#     dracon:weightedDegree 3 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/oberrichter/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/sechste_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Sechste Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 1 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/sechste_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/vierte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Vierte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 1 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/vierte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/zehnte_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Zehnte Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 1 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/zehnte_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/zweite_maske> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Zweite Maske [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/24> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.5510204081632653"^^xsd:float ;
#     dracon:degree 10 ;
#     dracon:eigenvector "0.24881260968181157"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 2 ;
#     dracon:weightedDegree 10 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/zweite_maske/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/zweiter_bedienter> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Zweiter Bedienter [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/19> ;
#     dracon:betweenness "0.0"^^xsd:float ;
#     dracon:closeness "0.38571428571428573"^^xsd:float ;
#     dracon:degree 2 ;
#     dracon:eigenvector "0.015131464848361604"^^xsd:float ;
#     dracon:has_numOfSpeechActs 1 ;
#     dracon:in_numOfScenes 1 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 10 ;
#     dracon:weightedDegree 2 ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/zweiter_bedienter/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/digitalsource/1> a crm:E73_Information_Object ;
#     rdfs:label "Digital Source of 'Richard Savage oder Der Sohn einer Mutter'" ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P16i_was_used_for <https://dracor.org/entity/ger000006/file/tei/in/preparation/1> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/digitalsource/1/id/url/1> ;
#     crm:P3_has_note "Provenance of file: TextGrid Repository" ;
#     rdfs:seeAlso <http://www.textgridrep.org/textgrid:p5c8.0> .
#
# <https://dracor.org/entity/ger000006/file/tei/in> a <http://www.ics.forth.gr/isl/CRMdig/D1_Digital_Object> ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [TEI-File that was ingested into the DraCor-Platform]" ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P2_has_type <https://dracor.org/entity/type/file/dracor-tei-source> ;
#     crm:P94i_was_created_by <https://dracor.org/entity/ger000006/file/tei/in/preparation/1> .
#
# <https://dracor.org/entity/ger000006/file/tei/in/preparation/1> a crm:E11_Modification,
#         crm:E65_Creation ;
#     rdfs:label "Preparation of TEI-File 'Richard Savage oder Der Sohn einer Mutter'" ;
#     crm:P16_used_specific_object <https://dracor.org/entity/ger000006/digitalsource/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/activity/editing> ;
#     crm:P94_has_created <https://dracor.org/entity/ger000006/file/tei/in> .
#
# <https://dracor.org/entity/ger000006/publication-expression/2> a frbroo:F24_Publication_Expression ;
#     rdfs:label "Richard Savage oder Der Sohn einer Mutter [Publication Expression]" ;
#     frbroo:CLR6i_should_be_carried_by <https://dracor.org/entity/ger000006/manifestation/2> ;
#     frbroo:R24i_was_created_through <https://dracor.org/entity/ger000006/publication/2> ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P3_has_note """The text 'Richard Savage oder Der Sohn einer Mutter', its layout and the textual and graphic content of front and back
# cover, spine of the publication Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912].""" .
#
# <https://dracor.org/entity/ger000006/segment/15> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Dritter Aufzug. | Zweite Szene. | Dritter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/3> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Erster Aufzug. | Erste Szene. | Dritter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/6> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Zweiter Aufzug. | Erste Szene. | Erster Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/steele> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/8> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Zweiter Aufzug. | Zweite Szene. | Dritter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/creation/0> a frbroo:F28_Expression_Creation ;
#     rdfs:label "Writing of 'Richard Savage oder Der Sohn einer Mutter', until it was first published." ;
#     frbroo:R19_created_a_realization_of <https://dracor.org/entity/ger000006/work> ;
#     crm:P134i_was_continued_by <https://dracor.org/entity/ger000006/creation/0/end> ;
#     crm:P14_carried_out_by <https://dracor.org/entity/Q76755> ;
#     crm:P2_has_type <https://dracor.org/entity/type/activity/writing> ;
#     crm:P4_has_time-span <https://dracor.org/entity/ger000006/creation/0/ts> .
#
# <https://dracor.org/entity/ger000006/segment/1> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Erster Aufzug. | Erste Szene. | Erster Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/miss_ellen>,
#         <https://dracor.org/entity/ger000006/character/steele> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/10> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Zweiter Aufzug. | Zweite Szene. | Fünfter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/lady>,
#         <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/13> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Dritter Aufzug. | Erste Szene. | Erster Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/haushofmeister>,
#         <https://dracor.org/entity/ger000006/character/miss_ellen> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/14> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Dritter Aufzug. | Erste Szene. | Zweiter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/lady>,
#         <https://dracor.org/entity/ger000006/character/miss_ellen> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/16> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Dritter Aufzug. | Zweite Szene. | Vierter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/savage>,
#         <https://dracor.org/entity/ger000006/character/steele> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/20> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Vierter Aufzug. | Erste Szene. | Dritter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/lord_tyrconnel>,
#         <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/21> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Vierter Aufzug. | Erste Szene. | Vierter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/dritter_bedienter>,
#         <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/26> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Fünfter Aufzug. | Erster Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/kitty>,
#         <https://dracor.org/entity/ger000006/character/toms> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/5> a dracon:segment,
#         crm:E33_Linguistic_Object ;
# ...
#         <https://dracor.org/entity/relation/d08c4c94a4e4825ec09fd3384039d1b7> ;
#     crm:P02i_is_range_of <https://dracor.org/entity/relation/5456c69811e39cf3693e24e6afc90846>,
#         <https://dracor.org/entity/relation/fbb022e635984407581f445d59e9c60a> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/toms/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/segment/25> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Vierter Aufzug. | Zweite Szene. | Achter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/alle_4-2-4>,
#         <https://dracor.org/entity/ger000006/character/lady>,
#         <https://dracor.org/entity/ger000006/character/lord_berwick>,
#         <https://dracor.org/entity/ger000006/character/lord_tyrconnel>,
#         <https://dracor.org/entity/ger000006/character/lord_winchester>,
#         <https://dracor.org/entity/ger000006/character/miss_ellen>,
#         <https://dracor.org/entity/ger000006/character/savage>,
#         <https://dracor.org/entity/ger000006/character/steele> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/segment/24> a dracon:segment,
#         crm:E33_Linguistic_Object ;
#     rdfs:label "Vierter Aufzug. | Zweite Szene. | Siebenter Auftritt. [Segment in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:has_speaker <https://dracor.org/entity/ger000006/character/achte_maske>,
#         <https://dracor.org/entity/ger000006/character/dritte_maske>,
#         <https://dracor.org/entity/ger000006/character/erste_maske>,
#         <https://dracor.org/entity/ger000006/character/fuenfte_maske>,
#         <https://dracor.org/entity/ger000006/character/neunte_maske>,
#         <https://dracor.org/entity/ger000006/character/savage>,
#         <https://dracor.org/entity/ger000006/character/sechste_maske>,
#         <https://dracor.org/entity/ger000006/character/steele>,
#         <https://dracor.org/entity/ger000006/character/vierte_maske>,
#         <https://dracor.org/entity/ger000006/character/zehnte_maske>,
#         <https://dracor.org/entity/ger000006/character/zweite_maske> ;
#     dracon:is_segment_of <https://dracor.org/entity/ger000006> ;
#     crm:P106i_forms_part_of <https://dracor.org/entity/ger000006> ;
#     crm:P2_has_type <https://dracor.org/entity/type/segment/scene> .
#
# <https://dracor.org/entity/ger000006/character/steele> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Steele [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/1>,
#         <https://dracor.org/entity/ger000006/segment/16>,
#         <https://dracor.org/entity/ger000006/segment/17>,
#         <https://dracor.org/entity/ger000006/segment/2>,
#         <https://dracor.org/entity/ger000006/segment/24>,
#         <https://dracor.org/entity/ger000006/segment/25>,
#         <https://dracor.org/entity/ger000006/segment/30>,
#         <https://dracor.org/entity/ger000006/segment/6>,
#         <https://dracor.org/entity/ger000006/segment/7> ;
#     dracon:betweenness "0.14617576156037693"^^xsd:float ;
#     dracon:closeness "0.7105263157894737"^^xsd:float ;
#     dracon:degree 17 ;
#     dracon:eigenvector "0.3354755732802925"^^xsd:float ;
#     dracon:has_numOfSpeechActs 58 ;
#     dracon:in_numOfScenes 9 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 3329 ;
#     dracon:weightedDegree 28 ;
#     crm:P01i_is_domain_of <https://dracor.org/entity/relation/3bd4694cd199a2a4a8f1217d28ae8940>,
#         <https://dracor.org/entity/relation/f32fa05a47a5b0e7b79c047783d3dab9> ;
#     crm:P02i_is_range_of <https://dracor.org/entity/relation/7aba7b7dc35696fa54d2d19e3ec1c1eb>,
#         <https://dracor.org/entity/relation/a71a6c3f6cce5baf315f852e8ebc64db> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/steele/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006/character/lady> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Lady [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/10>,
#         <https://dracor.org/entity/ger000006/segment/11>,
#         <https://dracor.org/entity/ger000006/segment/14>,
#         <https://dracor.org/entity/ger000006/segment/23>,
#         <https://dracor.org/entity/ger000006/segment/25>,
#         <https://dracor.org/entity/ger000006/segment/29>,
#         <https://dracor.org/entity/ger000006/segment/30>,
#         <https://dracor.org/entity/ger000006/segment/4>,
#         <https://dracor.org/entity/ger000006/segment/5> ;
#     dracon:betweenness "0.0663269778654394"^^xsd:float ;
#     dracon:closeness "0.6428571428571429"^^xsd:float ;
#     dracon:degree 12 ;
#     dracon:eigenvector "0.17487586903607158"^^xsd:float ;
#     dracon:has_numOfSpeechActs 81 ;
#     dracon:in_numOfScenes 9 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 2373 ;
#     dracon:weightedDegree 29 ;
#     crm:P01i_is_domain_of <https://dracor.org/entity/relation/535e050ffd55b85d5778a4e58705908a>,
#         <https://dracor.org/entity/relation/c99777d668157d28934d6210fd8ecb88>,
#         <https://dracor.org/entity/relation/cd7b7c28df1e00349f2c434069182c28> ;
#     crm:P02i_is_range_of <https://dracor.org/entity/relation/073f108617fcca3e5033885202fce7af>,
#         <https://dracor.org/entity/relation/0d159dfb6df55edf7994124bfb67297c>,
#         <https://dracor.org/entity/relation/75fdbd6b4a662a2535669af59543d3e8> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/lady/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/female> .
#
# <https://dracor.org/entity/ger000006/character/savage> a dracon:character,
#         frbroo:F38_Character ;
#     rdfs:label "Savage [Character in 'Richard Savage oder Der Sohn einer Mutter']" ;
#     dracon:appears_in_segment <https://dracor.org/entity/ger000006/segment/10>,
#         <https://dracor.org/entity/ger000006/segment/12>,
#         <https://dracor.org/entity/ger000006/segment/15>,
#         <https://dracor.org/entity/ger000006/segment/16>,
#         <https://dracor.org/entity/ger000006/segment/17>,
#         <https://dracor.org/entity/ger000006/segment/2>,
#         <https://dracor.org/entity/ger000006/segment/20>,
#         <https://dracor.org/entity/ger000006/segment/21>,
#         <https://dracor.org/entity/ger000006/segment/22>,
#         <https://dracor.org/entity/ger000006/segment/24>,
#         <https://dracor.org/entity/ger000006/segment/25>,
#         <https://dracor.org/entity/ger000006/segment/28>,
#         <https://dracor.org/entity/ger000006/segment/29>,
#         <https://dracor.org/entity/ger000006/segment/3>,
#         <https://dracor.org/entity/ger000006/segment/30>,
#         <https://dracor.org/entity/ger000006/segment/5>,
#         <https://dracor.org/entity/ger000006/segment/8>,
#         <https://dracor.org/entity/ger000006/segment/9> ;
#     dracon:betweenness "0.4117795310103001"^^xsd:float ;
#     dracon:closeness "0.84375"^^xsd:float ;
#     dracon:degree 22 ;
#     dracon:eigenvector "0.36774650723014357"^^xsd:float ;
#     dracon:has_numOfSpeechActs 99 ;
#     dracon:in_numOfScenes 18 ;
#     dracon:is_character_in <https://dracor.org/entity/ger000006> ;
#     dracon:speaks_numOfWords 5077 ;
#     dracon:weightedDegree 42 ;
#     crm:P01i_is_domain_of <https://dracor.org/entity/relation/7aba7b7dc35696fa54d2d19e3ec1c1eb>,
#         <https://dracor.org/entity/relation/a71a6c3f6cce5baf315f852e8ebc64db> ;
#     crm:P02i_is_range_of <https://dracor.org/entity/relation/3bd4694cd199a2a4a8f1217d28ae8940>,
#         <https://dracor.org/entity/relation/f32fa05a47a5b0e7b79c047783d3dab9> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/character/savage/appellation/1> ;
#     crm:P2_has_type <https://dracor.org/entity/type/gender/male> .
#
# <https://dracor.org/entity/ger000006> a dracon:play,
#         crmcls:X2_Corpus_Document ;
#     rdfs:label "Gutzkow, Karl: Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen"@ger ;
#     dracon:allInIndex 0.9 ;
#     dracon:allInSegment <https://dracor.org/entity/ger000006/segment/27> ;
#     dracon:averageClustering "0.787224283652855"^^xsd:float ;
#     dracon:averageDegree "8.142857142857142"^^xsd:float ;
#     dracon:averagePathLength "1.9153439153439153"^^xsd:float ;
#     dracon:density "0.30158730158730157"^^xsd:float ;
#     dracon:diameter 4 ;
#     dracon:has_character <https://dracor.org/entity/ger000006/character/achte_maske>,
#         <https://dracor.org/entity/ger000006/character/alle_4-2-4>,
#         <https://dracor.org/entity/ger000006/character/bedienter_der_lady>,
#         <https://dracor.org/entity/ger000006/character/bursche>,
#         <https://dracor.org/entity/ger000006/character/dritte_maske>,
#         <https://dracor.org/entity/ger000006/character/dritter_bedienter>,
#         <https://dracor.org/entity/ger000006/character/erste_maske>,
#         <https://dracor.org/entity/ger000006/character/erster_bedienter>,
#         <https://dracor.org/entity/ger000006/character/fuenfte_maske>,
#         <https://dracor.org/entity/ger000006/character/haushofmeister>,
#         <https://dracor.org/entity/ger000006/character/kitty>,
#         <https://dracor.org/entity/ger000006/character/lady>,
#         <https://dracor.org/entity/ger000006/character/lord_berwick>,
#         <https://dracor.org/entity/ger000006/character/lord_tyrconnel>,
#         <https://dracor.org/entity/ger000006/character/lord_winchester>,
#         <https://dracor.org/entity/ger000006/character/maennliche_stimme>,
#         <https://dracor.org/entity/ger000006/character/miss_ellen>,
#         <https://dracor.org/entity/ger000006/character/neunte_maske>,
#         <https://dracor.org/entity/ger000006/character/oberrichter>,
#         <https://dracor.org/entity/ger000006/character/savage>,
#         <https://dracor.org/entity/ger000006/character/sechste_maske>,
#         <https://dracor.org/entity/ger000006/character/steele>,
#         <https://dracor.org/entity/ger000006/character/toms>,
#         <https://dracor.org/entity/ger000006/character/vierte_maske>,
#         <https://dracor.org/entity/ger000006/character/viscount>,
#         <https://dracor.org/entity/ger000006/character/zehnte_maske>,
#         <https://dracor.org/entity/ger000006/character/zweite_maske>,
#         <https://dracor.org/entity/ger000006/character/zweiter_bedienter> ;
#     dracon:has_segment <https://dracor.org/entity/ger000006/segment/1>,
#         <https://dracor.org/entity/ger000006/segment/10>,
#         <https://dracor.org/entity/ger000006/segment/11>,
#         <https://dracor.org/entity/ger000006/segment/12>,
#         <https://dracor.org/entity/ger000006/segment/13>,
#         <https://dracor.org/entity/ger000006/segment/14>,
#         <https://dracor.org/entity/ger000006/segment/15>,
#         <https://dracor.org/entity/ger000006/segment/16>,
#         <https://dracor.org/entity/ger000006/segment/17>,
#         <https://dracor.org/entity/ger000006/segment/18>,
#         <https://dracor.org/entity/ger000006/segment/19>,
#         <https://dracor.org/entity/ger000006/segment/2>,
#         <https://dracor.org/entity/ger000006/segment/20>,
#         <https://dracor.org/entity/ger000006/segment/21>,
#         <https://dracor.org/entity/ger000006/segment/22>,
#         <https://dracor.org/entity/ger000006/segment/23>,
#         <https://dracor.org/entity/ger000006/segment/24>,
#         <https://dracor.org/entity/ger000006/segment/25>,
#         <https://dracor.org/entity/ger000006/segment/26>,
#         <https://dracor.org/entity/ger000006/segment/27>,
#         <https://dracor.org/entity/ger000006/segment/28>,
#         <https://dracor.org/entity/ger000006/segment/29>,
#         <https://dracor.org/entity/ger000006/segment/3>,
#         <https://dracor.org/entity/ger000006/segment/30>,
#         <https://dracor.org/entity/ger000006/segment/4>,
#         <https://dracor.org/entity/ger000006/segment/5>,
#         <https://dracor.org/entity/ger000006/segment/6>,
#         <https://dracor.org/entity/ger000006/segment/7>,
#         <https://dracor.org/entity/ger000006/segment/8>,
#         <https://dracor.org/entity/ger000006/segment/9> ;
#     dracon:in_corpus <https://dracor.org/entity/corpus/ger> ;
#     dracon:maxDegree 22 ;
#     dracon:maxDegreeCharacter <https://dracor.org/entity/ger000006/character/savage> ;
#     dracon:networkSize 28 ;
#     dracon:normalisedYear "1839-01-01"^^xsd:gYear ;
#     dracon:numConnectedComponents 1 ;
#     dracon:numOfActs 5 ;
#     dracon:numOfLines 25 ;
#     dracon:numOfParagraphs 480 ;
#     dracon:numOfSegments 30 ;
#     dracon:numOfSpeakerGroups 1 ;
#     dracon:numOfSpeakers 28 ;
#     dracon:numOfSpeakersFemale 3 ;
#     dracon:numOfSpeakersMale 24 ;
#     dracon:numOfSpeakersUnknown 1 ;
#     dracon:premiereYear "1839" ;
#     dracon:printYear "1842" ;
#     dracon:wikipediaLinkCount 0 ;
#     dracon:writtenYear "1839" ;
#     dc:creator "Gutzkow, Karl"@ger ;
#     dc:source "Gutzkows Werke. Auswahl in zwölf Teilen. Herausgegeben und mit einem Lebensbild versehen von Reinhold Gensel, Berlin, Leipzig, Wien, Stuttgart: Bong, [1912]." ;
#     dc:title "Richard Savage oder Der Sohn einer Mutter. Trauerspiel in fünf Aufzügen"@ger ;
#     crm:P102_has_title <https://dracor.org/entity/ger000006/title/main/ger>,
#         <https://dracor.org/entity/ger000006/title/sub/ger> ;
#     crm:P106_is_composed_of <https://dracor.org/entity/ger000006/segment/1>,
#         <https://dracor.org/entity/ger000006/segment/10>,
#         <https://dracor.org/entity/ger000006/segment/11>,
#         <https://dracor.org/entity/ger000006/segment/12>,
#         <https://dracor.org/entity/ger000006/segment/13>,
#         <https://dracor.org/entity/ger000006/segment/14>,
#         <https://dracor.org/entity/ger000006/segment/15>,
#         <https://dracor.org/entity/ger000006/segment/16>,
#         <https://dracor.org/entity/ger000006/segment/17>,
#         <https://dracor.org/entity/ger000006/segment/18>,
#         <https://dracor.org/entity/ger000006/segment/19>,
#         <https://dracor.org/entity/ger000006/segment/2>,
#         <https://dracor.org/entity/ger000006/segment/20>,
#         <https://dracor.org/entity/ger000006/segment/21>,
#         <https://dracor.org/entity/ger000006/segment/22>,
#         <https://dracor.org/entity/ger000006/segment/23>,
#         <https://dracor.org/entity/ger000006/segment/24>,
#         <https://dracor.org/entity/ger000006/segment/25>,
#         <https://dracor.org/entity/ger000006/segment/26>,
#         <https://dracor.org/entity/ger000006/segment/27>,
#         <https://dracor.org/entity/ger000006/segment/28>,
#         <https://dracor.org/entity/ger000006/segment/29>,
#         <https://dracor.org/entity/ger000006/segment/3>,
#         <https://dracor.org/entity/ger000006/segment/30>,
#         <https://dracor.org/entity/ger000006/segment/4>,
#         <https://dracor.org/entity/ger000006/segment/5>,
#         <https://dracor.org/entity/ger000006/segment/6>,
#         <https://dracor.org/entity/ger000006/segment/7>,
#         <https://dracor.org/entity/ger000006/segment/8>,
#         <https://dracor.org/entity/ger000006/segment/9> ;
#     crm:P148i_is_component_of <https://dracor.org/entity/corpus/ger> ;
#     crm:P165_incorporates <https://dracor.org/entity/ger000006/expression/2> ;
#     crm:P1_is_identified_by <https://dracor.org/entity/ger000006/id/dracor>,
#         <https://dracor.org/entity/ger000006/id/playname>,
#         <https://dracor.org/entity/ger000006/id/wikidata> ;
#     crm:P41i_was_classified_by <https://dracor.org/entity/activity/classification/86ae93a3fddf1524715ebd4e915f4ee3> ;
#     rdfs:seeAlso <https://dracor.org/ger/gutzkow-richard-savage> .

# %%
#Function to export a graph to a file:
def export_graph(path:str,filename:str,graph,export_format:str):
    export_file_path = path + "/" + filename + "." + export_format
    graph.serialize(destination=export_file_path, format=export_format)

# %%
# !mkdir export

# %%
# !ls
# Out:
# export                             prepare-rdf-4-research-space.ipynb

# %%
import os

# %%
#function to export a corpus as rdf
def export_corpus(corpusname:str):
    #get plays of a corpus
    plays = get(corpusname=corpusname, parse_json=True, apibase="http://localhost:8080/exist/restxq/")["dramas"]
    
    
    path = "export/" + corpusname 
    
    #create directory:
    #os.makedirs(path)
    
    for play in plays:
        playname = play["name"]
        print(playname)
        #get the rdf
        try:
            play_g = get_rdf(corpusname, playname)
        except:
            print("Could not get/parse " + corpusname + " " + playname)
            
        #store
        filepath = path + "/" + playname + ".ttl"
        play_g.serialize(destination=filepath, format="ttl")
        print("Exported " + playname)
        
    print("Exported " + corpusname)

# %%
export_corpus("span")
# Out:
# clarin-teresa
# Exported clarin-teresa
# dicenta-juan-jose
# Exported dicenta-juan-jose
# echegaray-arrastrarse
# Exported echegaray-arrastrarse
# echegaray-mancha
# Exported echegaray-mancha
# galdos-casandra
# Exported galdos-casandra
# galdos-electra
# Exported galdos-electra
# galdos-perfecta
# Exported galdos-perfecta
# lorca-bernarda
# Exported lorca-bernarda
# lorca-bodas
# Exported lorca-bodas
# lorca-rosita
# Exported lorca-rosita
# lorca-yerma
# Exported lorca-yerma
# lorca-zapatera
# Exported lorca-zapatera
# munoz-conferencia
# Exported munoz-conferencia
# munoz-ortiz
# Exported munoz-ortiz
# munoz-pergaminos
# Exported munoz-pergaminos
# munoz-refugio
# Exported munoz-refugio
# unamuno-esfinge
# Exported unamuno-esfinge
# unamuno-fedra
# Exported unamuno-fedra
# valera-asclepigenia
# Exported valera-asclepigenia
# valera-atahualpa
# Exported valera-atahualpa
# valle-aguila
# Exported valle-aguila
# valle-cara
# Exported tasso-re-torrismondo
# torelli-la-merope
# Exported torelli-la-merope
# trissino-sofonisba
# Exported trissino-sofonisba
# della-valle-la-reina-di-scozia
# Exported della-valle-la-reina-di-scozia
# visconti-pasitea
# Exported visconti-pasitea
# Exported ita

# %%
export_corpus("ger")
# Out:
# alberti-brot
# Exported alberti-brot
# alberti-im-suff
# Exported alberti-im-suff
# andre-der-comoedienfeind
# Exported andre-der-comoedienfeind
# anzengruber-das-vierte-gebot
# Exported anzengruber-das-vierte-gebot
# anzengruber-der-gwissenswurm
# Exported anzengruber-der-gwissenswurm
# anzengruber-der-meineidbauer
# Exported anzengruber-der-meineidbauer
# anzengruber-der-pfarrer-von-kirchfeld
# Exported anzengruber-der-pfarrer-von-kirchfeld
# anzengruber-die-kreuzelschreiber
# Exported anzengruber-die-kreuzelschreiber
# anzengruber-heimgfunden
# Exported anzengruber-heimgfunden
# arnim-das-loch
# Exported arnim-das-loch
# arnim-halle
# Exported arnim-halle
# arnim-jerusalem
# Exported arnim-jerusalem
# arnim-marino-caboga
# Exported arnim-marino-caboga
# auenbrugger-der-rauchfangkehrer
# Exported auenbrugger-der-rauchfangkehrer
# avenarius-faust
# Exported avenarius-faust
# ayrenhoff-der-postzug
# Exported ayrenhoff-der-postzug
# ayrenhoff-virginia
# Exported ayrenhoff-virginia
# ball-die-nase-des-michelangelo
# Exported ball-die-nase-des-michelangelo
# barlach-der-blaue-boll
# Exported barlach-der-blaue-boll
# bauernfeld-buergerlich-und-romantisch
# Exported bauernfeld-buergerlich-und-romantisch
# bauernfeld-grossjaehrig
# Exported bauernfeld-grossjaehrig
# bauernfeld-industrie-und-herz
# Exported bauernfeld-industrie-und-herz
# beer-der-paria
# Exported beer-der-paria
# beer-struensee
# Exported beer-struensee
# benedix-das-bemooste-haupt
# Exported benedix-das-bemooste-haupt
# benedix-die-hochzeitsreise
# Exported benedix-die-hochzeitsreise
# benedix-die-luegnerin
# Exported benedix-die-luegnerin
# benedix-doctor-wespe
# Exported benedix-doctor-wespe
# benkowitz-die-jubelfeier-der-hoelle
# Exported benkowitz-die-jubelfeier-der-hoelle
# berg-kalisch-berlin-wie-es-weint-und-lacht
# Exported berg-kalisch-berlin-wie-es-weint-und-lacht
# bernard-faust
# Exported bernard-faust
# birch-pfeiffer-die-walpurgisnacht
# Exported birch-pfeiffer-die-walpurgisnacht
# birch-pfeiffer-in-der-heimath
# Exported birch-pfeiffer-in-der-heimath
# birch-pfeiffer-johannes-gutenberg
# Exported birch-pfeiffer-johannes-gutenberg
# birch-pfeiffer-pfeffer-roesel
# Exported birch-pfeiffer-pfeffer-roesel
# birch-pfeiffer-vatersorgen
# Exported birch-pfeiffer-vatersorgen
# bleibtreu-ein-faust-der-that
# Exported bleibtreu-ein-faust-der-that
# bleibtreu-weltgericht
# Exported bleibtreu-weltgericht
# blumenthal-im-weissen-roessl
# Exported blumenthal-im-weissen-roessl
# bodmer-odoardo-galotti-vater-der-emilia
# Exported bodmer-odoardo-galotti-vater-der-emilia
# borchert-draussen-vor-der-tuer
# Exported rosenow-die-im-schatten-leben
# rosenow-kater-lampe
# Exported rosenow-kater-lampe
# rubiner-die-gewaltlosen
# Exported rubiner-die-gewaltlosen
# ruederer-die-fahnenweihe
# Exported ruederer-die-fahnenweihe
# schaefer-faustine-der-weibliche-faust
# Exported schaefer-faustine-der-weibliche-faust
# scheerbart-das-dumme-luder
# Exported scheerbart-das-dumme-luder
# scheerbart-das-gift
# Exported scheerbart-das-gift
# scheerbart-das-mirakel
# Exported scheerbart-das-mirakel
# scheerbart-der-alte-petrus
# Exported scheerbart-der-alte-petrus
# scheerbart-der-fanatische-buergermeister
# Exported scheerbart-der-fanatische-buergermeister
# scheerbart-der-herr-vom-jenseits
# Exported scheerbart-der-herr-vom-jenseits
# scheerbart-der-regierungswechsel
# Exported scheerbart-der-regierungswechsel
# scheerbart-der-schornsteinfeger
# Exported scheerbart-der-schornsteinfeger
# scheerbart-der-vornehme-raeuberhauptmann
# Exported scheerbart-der-vornehme-raeuberhauptmann
# scheerbart-der-wetterfuerst
# Exported scheerbart-der-wetterfuerst
# scheerbart-die-lustigen-raeuber
# Exported scheerbart-die-lustigen-raeuber
# scheerbart-die-puppe-und-die-dauerwurst
# Exported scheerbart-die-puppe-und-die-dauerwurst
# scheerbart-die-urgrossmutter
# Exported scheerbart-die-urgrossmutter
# scheerbart-die-welt-geht-unter
# Exported scheerbart-die-welt-geht-unter
# scheerbart-die-wurzeln-der-wohlhabenheit
# Exported scheerbart-die-wurzeln-der-wohlhabenheit
# scheerbart-es-lebe-europa
# Exported scheerbart-es-lebe-europa
# scheerbart-herr-kammerdiener-kneetschke
# Exported scheerbart-herr-kammerdiener-kneetschke
# scheerbart-lachende-gespenster
# Exported scheerbart-lachende-gespenster
# scheerbart-okurirasuna
# Exported scheerbart-okurirasuna
# scheerbart-ruebezahl
# Exported scheerbart-ruebezahl
# schikaneder-die-zauberfloete
# Exported schikaneder-die-zauberfloete
# schiller-die-braut-von-messina
# Exported schiller-die-braut-von-messina
# schiller-die-jungfrau-von-orleans
# Exported schiller-die-jungfrau-von-orleans
# schiller-die-piccolomini
# Exported schiller-die-piccolomini
# schiller-die-raeuber
# Exported schiller-die-raeuber
# schiller-die-verschwoerung-des-fiesco-zu-genua
# Exported schiller-die-verschwoerung-des-fiesco-zu-genua
# schiller-don-carlos-infant-von-spanien
# Exported schiller-don-carlos-infant-von-spanien
# schiller-kabale-und-liebe
# Exported schiller-kabale-und-liebe
# schiller-maria-stuart
# Exported schiller-maria-stuart
# schiller-wallensteins-lager
# Exported schiller-wallensteins-lager
# schiller-wallensteins-tod
# Exported schiller-wallensteins-tod
# schiller-wilhelm-tell
# Exported schiller-wilhelm-tell
# schink-der-neue-doktor-faust
# Exported schink-der-neue-doktor-faust
# schink-hanswurst-von-salzburg-mit-dem-hoelzernen-gat
# Exported schink-hanswurst-von-salzburg-mit-dem-hoelzernen-gat
# schlaf-meister-oelze
# Exported schlaf-meister-oelze
# schlegel-jon
# Exported schlegel-jon
# schlegel-alarcos
# Exported schlegel-alarcos
# Exported weissenthurn-das-manuscript
# weissenthurn-die-schwestern-st-janvier
# Exported weissenthurn-die-schwestern-st-janvier
# weissenthurn-johann-herzog-von-finnland
# Exported weissenthurn-johann-herzog-von-finnland
# weissenthurn-welche-ist-die-braut
# Exported weissenthurn-welche-ist-die-braut
# weissenthurn-welcher-ist-der-braeutigam
# Exported weissenthurn-welcher-ist-der-braeutigam
# werner-der-vierundzwanzigste-februar
# Exported werner-der-vierundzwanzigste-februar
# wette-haensel-und-gretel
# Exported wette-haensel-und-gretel
# widmann-der-widerspenstigen-zaehmung
# Exported widmann-der-widerspenstigen-zaehmung
# widmann-maikaefer-komoedie
# Exported widmann-maikaefer-komoedie
# wieland-alceste
# Exported wieland-alceste
# wieland-klementina-von-porretta
# Exported wieland-klementina-von-porretta
# wieland-lady-johanna-gray
# Exported wieland-lady-johanna-gray
# wilbrandt-der-meister-von-palmyra
# Exported wilbrandt-der-meister-von-palmyra
# wilbrandt-gracchus-der-volkstribun
# Exported wilbrandt-gracchus-der-volkstribun
# wildenbruch-die-haubenlerche
# Exported wildenbruch-die-haubenlerche
# wildenbruch-die-karolinger
# Exported wildenbruch-die-karolinger
# wildenbruch-die-quitzows
# Exported wildenbruch-die-quitzows
# wildgans-armut
# Exported wildgans-armut
# wildgans-dies-irae
# Exported wildgans-dies-irae
# wildgans-in-ewigkeit-amen
# Exported wildgans-in-ewigkeit-amen
# wohlbrueck-der-vampyr
# Exported wohlbrueck-der-vampyr
# wolfram-faust
# Exported wolfram-faust
# zedlitz-herr-und-sklave
# Exported zedlitz-herr-und-sklave
# zschokke-abellino
# Exported zschokke-abellino
# delpons-der-ahnherr
# Exported delpons-der-ahnherr
# Exported ger

# %%
export_corpus("swe")
# Out:
# agrell-domd
# Exported agrell-domd
# agrell-en-hufvudsak
# Exported agrell-en-hufvudsak
# agrell-en-lektion
# Exported agrell-en-lektion
# agrell-ensam
# Exported agrell-ensam
# agrell-hvarfor
# Exported agrell-hvarfor
# agrell-ingrid-en-dods-karlekssaga
# Exported agrell-ingrid-en-dods-karlekssaga
# agrell-smastadslif
# Exported agrell-smastadslif
# aurelius-farmors-fodelsedag
# /Library/anaconda3/lib/python3.6/site-packages/rdflib/term.py:1276: UserWarning: Serializing weird numerical rdflib.term.Literal('', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal'))
#   warnings.warn("Serializing weird numerical %r" % self)
# Exported aurelius-farmors-fodelsedag
# barthelson-efterspel
# Exported barthelson-efterspel
# benedictsson-final
# Exported benedictsson-final
# benedictsson-itelefon
# Exported benedictsson-itelefon
# benedictsson-romeos-julia
# Exported benedictsson-romeos-julia
# bremer-konstnarns-fortviflan
# Exported bremer-konstnarns-fortviflan
# geijerstam-lars-anders-och-jan-anders-och-deras-barn
# Exported geijerstam-lars-anders-och-jan-anders-och-deras-barn
# hedberg-rospiggarna
# Exported hedberg-rospiggarna
# indebetou-idet-grona
# Exported indebetou-idet-grona
# indebetou-ifruntimmersveckan
# Exported indebetou-ifruntimmersveckan
# indebetou-pa-fotvandring
# Exported indebetou-pa-fotvandring
# kullgren-karlek
# Exported kullgren-karlek
# kuylenstierna-nar-nyar-kom
# Exported kuylenstierna-nar-nyar-kom
# kuylenstierna-nu-ar-det-jul-igen
# Exported kuylenstierna-nu-ar-det-jul-igen
# leffler-den-karleken
# Exported leffler-den-karleken
# leffler-elfvan
# Exported leffler-elfvan
# leffler-familjelycka
# Exported leffler-familjelycka
# leffler-hur-man-gor-godt
# Exported leffler-hur-man-gor-godt
# leffler-moster-malvina
# Exported leffler-moster-malvina
# leffler-sanna-kvinnor
# Exported leffler-sanna-kvinnor
# leffler-skadespelerskan
# Exported leffler-skadespelerskan
# leffler-under-toffeln
# Exported leffler-under-toffeln
# lindhe-modrar
# Exported lindhe-modrar
# lundberg-forlat-mig
# Exported lundberg-forlat-mig
# malling-fru-leonora
# Exported malling-fru-leonora
# marholm-otteringning
# Exported marholm-otteringning
# meyerson-den-nya-klassen
# Exported meyerson-den-nya-klassen
# meyerson-ett-pojkstreck
# Exported meyerson-ett-pojkstreck
# molander-varflod
# Exported molander-varflod
# strindberg-anno-fyrtiatta
# Exported strindberg-anno-fyrtiatta
# strindberg-bandet
# Exported strindberg-bandet
# strindberg-den-starkare
# Exported strindberg-den-starkare
# strindberg-fadren
# Exported strindberg-fadren
# strindberg-fordringsegare
# Exported strindberg-fordringsegare
# strindberg-forsta-varningen
# Exported strindberg-forsta-varningen
# strindberg-froken-julie
# Exported strindberg-froken-julie
# strindberg-gillets-hemlighet
# Exported strindberg-gillets-hemlighet
# strindberg-herr-bengts-hustru
# Exported strindberg-herr-bengts-hustru
# strindberg-hostslask
# Exported strindberg-hostslask
# strindberg-infor-doden
# Exported strindberg-infor-doden
# strindberg-kamraterna
# Exported strindberg-kamraterna
# strindberg-lycko-pers-resa
# Exported strindberg-lycko-pers-resa
# strindberg-marodorer
# Exported strindberg-marodorer
# strindberg-master-olof
# Exported strindberg-master-olof
# strindberg-moderskarlek
# Exported strindberg-moderskarlek
# strindberg-paria
# Exported strindberg-paria
# strindberg-samum
# Exported strindberg-samum
# strindberg-till-damaskus
# Exported strindberg-till-damaskus
# topelius-t-isma-maffarnas-land
# Exported topelius-t-isma-maffarnas-land
# topelius-t-jeppe-och-murra
# Exported topelius-t-jeppe-och-murra
# topelius-z-askungen
# Exported topelius-z-askungen
# topelius-z-jennys-formaningar
# Exported topelius-z-jennys-formaningar
# topelius-z-krypskyttarne
# Exported topelius-z-krypskyttarne
# topelius-z-lucias-ziffror
# Exported topelius-z-lucias-ziffror
# topelius-z-perdita
# Exported topelius-z-perdita
# topelius-z-skogskonungen
# Exported topelius-z-skogskonungen
# topelius-z-snurran
# Exported topelius-z-snurran
# topelius-z-station-sylvester
# Exported topelius-z-station-sylvester
# topelius-z-tidernas-spegel
# Exported topelius-z-tidernas-spegel
# wahlenberg-pa-vakt
# Exported wahlenberg-pa-vakt
# wahlenberg-tva-valsprak
# Exported wahlenberg-tva-valsprak
# Exported swe

# %% [markdown]
# ## Corpus Metadata

# %%
# implemented an local endpoint to quickly get the rdf serialization of metadata of a corpus
# http://localhost:8080/exist/restxq/corpora/ger/generate-rdf
corpusname = "ger"
method = "generate-rdf"


test_rdf = get(method=method, corpusname=corpusname, parse_json=False, apibase="http://localhost:8080/exist/restxq/")
print(test_rdf)
# Out:
# <rdf:RDF xmlns:schema="http://schema.org/" xmlns:owl="http://www.w3.org/2002/07/owl#" xmlns:crmcls="https://clsinfra.io/ontologies/CRMcls/" xmlns:dracon="http://dracor.org/ontology#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:crm="http://www.cidoc-crm.org/cidoc-crm/" xmlns:frbroo="http://iflastandards.info/ns/fr/frbr/frbroo/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/ger">
#         <rdf:type rdf:resource="http://dracor.org/ontology#corpus"/>
#         <rdf:type rdf:resource="https://clsinfra.io/ontologies/CRMcls/X1_Corpus"/>
#         <rdfs:label>German Drama Corpus</rdfs:label>
#         <crmcls:Y1i_is_subcorpus_of rdf:resource="https://dracor.org/entity/corpus/dracor"/>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/corpus/ger/id/corpusname"/>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/corpus/ger/title/acronym"/>
#         <crm:P1_is_identified_by rdf:resource="https://dracor.org/entity/corpus/ger/title/full"/>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/ger/id/corpusname">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E42_Identifier"/>
#         <crm:P2_has_type rdf:resource="https://dracor.org/entity/type/id/corpusname"/>
#         <rdfs:label>DraCor Identifier 'corpusname' of corpus 'German Drama Corpus'</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/corpus/ger"/>
#         <rdf:value>ger</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/ger/title/acronym">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <crm:P2_has_type rdf:resource="https://core.clscor.io/entity/type/acronym"/>
#         <rdfs:label>clscor 'acronym' of DraCor corpus 'German Drama Corpus'</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/corpus/ger"/>
#         <rdf:value>GerDraCor</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/ger/title/full">
#         <rdf:type rdf:resource="http://www.cidoc-crm.org/cidoc-crm/E41_Appellation"/>
#         <crm:P2_has_type rdf:resource="https://core.clscor.io/entity/type/full_title"/>
#         <rdfs:label>clscor 'full title' of DraCor corpus 'German Drama Corpus'</rdfs:label>
#         <crm:P1i_identifies rdf:resource="https://dracor.org/entity/corpus/ger"/>
#         <rdf:value>German Drama Corpus</rdf:value>
#     </rdf:Description>
#     <rdf:Description rdf:about="https://dracor.org/entity/corpus/dracor">
#         <crmcls:Y1_has_subcorpus rdf:resource="https://dracor.org/entity/corpus/ger"/>
#     </rdf:Description>
# </rdf:RDF>

# %%
# !ls export
# Out:
# als          ger          greek        rom          span
# cal          ger_not_fork ita          rus          swe

# %%
ger_meta_text = get(method="generate-rdf", corpusname="ger", parse_json=False, apibase="http://localhost:8080/exist/restxq/")
ger_meta_g = rdflib.Graph().parse(data=ger_meta_text, format='xml')
ger_meta_g.serialize(destination="export/meta/gerdracor_meta.ttl", format="ttl")
